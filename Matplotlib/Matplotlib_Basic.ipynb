# %% [markdown]
# # Matplotlib

# %% [markdown]
# Import libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# $x = [0, 1, 2, 3, 4, 5, 6, ..... 100]$
#
# $y1 = x^2$
#
# $y2 = x^3$

# %%
x = [i for i in range(101)]
y1 = [i**2 for i in x]
y2 = [i**3 for i in x]
print(y1)
print(y2)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096, 4225, 4356, 4489, 4624, 4761, 4900, 5041, 5184, 5329, 5476, 5625, 5776, 5929, 6084, 6241, 6400, 6561, 6724, 6889, 7056, 7225, 7396, 7569, 7744, 7921, 8100, 8281, 8464, 8649, 8836, 9025, 9216, 9409, 9604, 9801, 10000]
# ...

# %% [markdown]
# PLOTTING!

# %%
plt.plot(x,y1)

# %%
plt.plot(x,y2)

# %%
plt.figure(figsize=(15,5))#for figure size
plt.plot(x,y1)
plt.plot(x,y2)
plt.title('I Love Cats!', fontsize=16)#for title of the figure
plt.xlabel('X AXIS', fontsize=13)#for x label
plt.ylabel('Y AXIS', fontsize=13)#for y label
plt.legend(['Quadratic', 'Cubic'], loc=0)#legend is to differentiate from 2 figures.

# %% [markdown]
# # Figure & Axis

# %% [markdown]
# Plotting

# %%
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1, 2, 1)#adding subplot
ax2 = fig.add_subplot(1, 2, 2)

#figure 1
ax1.plot(x,y1)
ax1.set_title('Quadratic')
ax1.set_xlabel('X AXIS')
ax1.set_ylabel('Y AXIS')

#figure 2
ax2.plot(x,y2)
ax2.set_title('Cubic')
ax2.set_xlabel('X AXIS')
ax2.set_ylabel('Y AXIS')
# Out:
# Text(0, 0.5, 'Y AXIS')

# %% [markdown]
# plot functions

# %%
#here v r going to save the figure object and return it in a function
def duel_plot(x,y1,y2):
    
    fig = plt.figure(figsize=(15,5))
    ax1 = fig.add_subplot(1, 2, 1)
    ax2 = fig.add_subplot(1, 2, 2)

    ax1.plot(x,y1)
    ax1.set_title('Quadratic')
    ax1.set_xlabel('X AXIS')
    ax1.set_ylabel('Y AXIS')

    ax2.plot(x,y2)
    ax2.set_title('Cubic')
    ax2.set_xlabel('X AXIS')
    ax2.set_ylabel('Y AXIS')
    
    return fig

# %%
print(duel_plot(x,y1,y2))
# Out:
# Figure(1080x360)

# %% [markdown]
# # 2d Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from numpy.random import normal,rand

# %% [markdown]
# Line

# %%
a = np.linspace(0,10,100)#a will be our domain(linspace is used for line plot)
b = np.exp(-a)#b will be our y axis(exp is exponential plot)
plt.plot(a,b)
plt.show()

# %% [markdown]
# Histogram

# %%
x = normal(size=200)#here v r using numpy.random function.(normal distrubution)
plt.hist(x,bins=30)#hist is histogram function.bins function used for separating x values
plt.show()

# %% [markdown]
# Scatter Plot

# %%
a = rand(100)
b = rand(100)
plt.scatter(a,b)
plt.show()

# %% [markdown]
# Polar

# %%
r = np.arange(0, 3.0, 0.01)#RADIUS
theta = 2 * np.pi *r
ax = plt.subplot(111, projection='polar')
ax.plot(theta, r, color='r', linewidth=3)
ax.set_rmax(2.0)

# %% [markdown]
# # 3d Plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#for 3d axis
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %% [markdown]
# Line

# %%
import matplotlib as mpl

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection = "3d")
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label="parametric curve")
ax.legend()

plt.show()

# %% [markdown]
# Scatter

# %%
def randrange(n, vmin, vmax):
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection = '3d')
n = 100
for c, m, zl, zh in [('r', 'o', -50, -25),('b','^',-30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zl, zh)
    ax.scatter(xs, ys, zs, c=c, marker=m)
    
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# Wireframe

# %%
from mpl_toolkits.mplot3d import axes3d

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection= '3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_wireframe(X, Y, Z, rstride=10, cstride= 10)#row and column spacing.

plt.show()

# %% [markdown]
# Surface

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')

u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)

x = 10 * np.outer(np.cos(u), np.sin(v))
y = 10 * np.outer(np.sin(u), np.sin(v))
z = 10 * np.outer(np.ones(np.size(u)), np.cos(v))
ax.plot_surface(x, y, z, rstride=4, cstride=4, color='b')

plt.show()

# %% [markdown]
# Contour

# %%
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contour(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %% [markdown]
# Polygon

# %%
from matplotlib.collections import PolyCollection
from matplotlib.colors import colorConverter


fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')


def cc(arg):
    return colorConverter.to_rgba(arg, alpha=0.6)

xs = np.arange(0, 10, 0.4)
verts = []
zs = [0.0, 1.0, 2.0, 3.0]
for z in zs:
    ys = np.random.rand(len(xs))
    ys[0], ys[-1] = 0, 0
    verts.append(list(zip(xs, ys)))

poly = PolyCollection(verts, facecolors=[cc('r'), cc('g'), cc('b'),
                                         cc('y')])
poly.set_alpha(0.7)
ax.add_collection3d(poly, zs=zs, zdir='y')

ax.set_xlabel('X')
ax.set_xlim3d(0, 10)
ax.set_ylabel('Y')
ax.set_ylim3d(-1, 4)
ax.set_zlabel('Z')
ax.set_zlim3d(0, 1)

plt.show()

# %% [markdown]
# Bar

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# Quiver

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')

x, y, z = np.meshgrid(np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.2),
                      np.arange(-0.8, 1, 0.8))

u = np.sin(np.pi * x) * np.cos(np.pi * y) * np.cos(np.pi * z)
v = -np.cos(np.pi * x) * np.sin(np.pi * y) * np.cos(np.pi * z)
w = (np.sqrt(2.0 / 3.0) * np.cos(np.pi * x) * np.cos(np.pi * y) *
     np.sin(np.pi * z))

ax.quiver(x, y, z, u, v, w, length=0.1)

plt.show()
